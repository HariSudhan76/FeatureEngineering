# %% [markdown]
# <a href="https://colab.research.google.com/github/HariSudhan76/FeatureEngineering/blob/Missing-Data-Imputation/Simple_Imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cols_to_use = ["OverallQual",
               "TotalBsmtSF",
               "1stFlrSF",
               "GrLivArea",
               "BsmtUnfSF",
               "GarageArea",
               "SalePrice",
               "LotFrontage",
               "MasVnrArea",
               "GarageYrBlt",
               "FireplaceQu"
               ]
data = pd.read_csv("/content/gdrive/My Drive/ML Code/Missing Data/houseprice.csv",usecols=cols_to_use)
data.head()
# Out:
#    LotFrontage  OverallQual  MasVnrArea  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0         65.0            7       196.0        150          856       856
# 1         80.0            6         0.0        284         1262      1262
# 2         68.0            7       162.0        434          920       920
# 3         60.0            7         0.0        540          756       961
# 4         84.0            8       350.0        490         1145      1145
#
#    GrLivArea FireplaceQu  GarageYrBlt  GarageArea  SalePrice
# 0       1710         NaN       2003.0         548     208500
# 1       1262          TA       1976.0         460     181500
# 2       1786          TA       2001.0         608     223500
# 3       1717          Gd       1998.0         642     140000
# 4       2198          TA       2000.0         836     250000

# %%
x_train, x_test, y_train, y_test = train_test_split(
    data.drop("SalePrice", axis=1),
    data["SalePrice"],
    test_size=0.3,
    random_state=0
)
x_train.shape, x_test.shape
# Out:
# ((1022, 10), (438, 10))

# %%
var_list = [var for var in x_train.columns if x_train[var].isnull().sum()>0]
var_cat = list(x_train[var_list].select_dtypes(exclude="number").columns)
var_num = list(x_train[var_list].select_dtypes(include="number").columns)

# %%
imp_mean = ColumnTransformer(
    [("num_imp",
        SimpleImputer(strategy="mean"),var_num),
        ("cat_imp",
         SimpleImputer(strategy="most_frequent"),var_cat)
    ],remainder='passthrough').set_output(transform="pandas")

imp_mean.fit(x_train)
x_train=imp_mean.transform(x_train)

# %%
x_train.isnull().sum()
# Out:
# num_imp__LotFrontage      0
# num_imp__MasVnrArea       0
# num_imp__GarageYrBlt      0
# cat_imp__FireplaceQu      0
# remainder__OverallQual    0
# remainder__BsmtUnfSF      0
# remainder__TotalBsmtSF    0
# remainder__1stFlrSF       0
# remainder__GrLivArea      0
# remainder__GarageArea     0
# dtype: int64

# %%
imp_mean = ColumnTransformer(
    [("num_imp",
        SimpleImputer(strategy="mean"),var_num),
        ("cat_imp",
         SimpleImputer(strategy="most_frequent"),var_cat)
    ],remainder='passthrough')

x_train = pd.DataFrame(imp_mean.fit_transform(x_train),
             columns=x_train.columns)
x_train.isnull().sum()
# Out:
# LotFrontage    0
# OverallQual    0
# MasVnrArea     0
# BsmtUnfSF      0
# TotalBsmtSF    0
# 1stFlrSF       0
# GrLivArea      0
# FireplaceQu    0
# GarageYrBlt    0
# GarageArea     0
# dtype: int64
